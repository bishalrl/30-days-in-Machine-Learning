# %%
import pandas as pd
import requests

# %% [markdown]
# ## API key from IMDB

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=45e9a9399bc6d187721b814112f4a11c&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %%
df.shape
# Out:
# (20, 6)

# %%
df.head(5)
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  vote_average
# 0  Framed in the 1940s for the double murder of h...     122.319         8.704
# 1  Spanning the years 1945 to 1955, a chronicle o...     139.712         8.695
# 2  In the continuing saga of the Corleone crime f...      95.296         8.577
# 3  The true story of how businessman Oskar Schind...      79.114         8.567
# 4  The defense and the prosecution have rested an...      48.300         8.542

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=45e9a9399bc6d187721b814112f4a11c&language=en-US&page=5')

# %%
df1=pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %%
df1.head(5)
# Out:
#        id                         title release_date  \
# 0  632632                         Given   2020-08-22
# 1  637920         Miracle in Cell No. 7   2019-10-10
# 2   25237                  Come and See   1985-10-17
# 3  533514  Violet Evergarden: The Movie   2020-09-18
# 4   10376            The Legend of 1900   1998-10-28
#
#                                             overview  popularity  vote_average
# 0  The relationship between a band's bassist, the...      20.201         8.269
# 1  Separated from his daughter, a father with an ...      37.208         8.268
# 2  The invasion of a village in Byelorussia by Ge...      30.017         8.267
# 3  As the world moves on from the war and technol...      32.882         8.264
# 4  The story of a virtuoso piano player who lives...      21.735         8.263

# %%
df1.to_csv('movie1_csv')

# %%
df1
# Out:
#         id                                              title release_date  \
# 0   632632                                              Given   2020-08-22
# 1   637920                              Miracle in Cell No. 7   2019-10-10
# 2    25237                                       Come and See   1985-10-17
# 3   533514                       Violet Evergarden: The Movie   2020-09-18
# 4    10376                                 The Legend of 1900   1998-10-28
# 5   652837                      Josee, the Tiger and the Fish   2020-12-25
# 6      670                                             Oldboy   2003-11-21
# 7     8587                                      The Lion King   1994-06-24
# 8   299534                                  Avengers: Endgame   2019-04-24
# 9   630566                                             Clouds   2020-10-09
# 10  508965                                              Klaus   2019-11-08
# ...
